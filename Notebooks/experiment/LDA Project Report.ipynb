# %% [markdown]
# ### LDA Core Mininimal Implementation with Tf-idf and K-means
#
# In addition to the current implementation of LDA Core with Word2Vec and SOM, this notebook provides an alternative method of anomaly detection by encoding a fixed log data file with Tf-idf and identifying log anomalies with the unsupervised machine learning algorithm K-means.

# %% [markdown]
# ### Import packages

# %%
import os
import time
import nltk
import numpy as np
import logging
import pickle
import sompy
from multiprocessing import Pool
from itertools import product
import pandas as pd
import re
import gensim as gs
import matplotlib.pyplot as plt
from scipy.spatial.distance import cosine
from sklearn.preprocessing import normalize
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.cluster import KMeans;
from nltk.cluster import KMeansClusterer

# %% [markdown]
# ### Define our Functions
#
# #### 1. Log Preprocesing
#
# One assumption that all these functions use is that we instantly convert our data into a pandas dataframe that has a "messages" column containing the relevent information for us.
#
# We then treat each individual log line as a "word", cleaning it by removing all non-alphabet charcters including white spaces.

# %%
def _preprocess(data):
    for col in data.columns:
        if col == "messages":
            data[col] = data[col].apply(_clean_message)
        else:
            data[col] = data[col].apply(to_str)

    data = data.fillna("EMPTY")
    
def _clean_message(line):
    """Remove all none alphabetical characters from message strings."""
    return "".join(
        re.findall("[a-zA-Z]+", line)
    )  # Leaving only a-z in there as numbers add to anomalousness quite a bit

def to_str(x):
    """Convert all non-str lists to string lists for Word2Vec."""
    ret = " ".join([str(y) for y in x]) if isinstance(x, list) else str(x)
    return ret

# %% [markdown]
# Function below transfers the original data into ideal dataframe based on user's preference for further analysis.

# %%
def merge_logs_by_unit(data, unit = 'log', tfidf = False):
    messages = data[['messages']]
    n_row = data.shape[0]
    df = pd.DataFrame(columns=['messages'])
    result = []

    for i in range(n_row):
        if unit == 'application': 
            message = pd.DataFrame({'messages':[np.array_str(messages.iloc[i].values)]})  
        elif unit == 'log':   
            message = pd.DataFrame({'messages':messages.iloc[i].values})
            message = message.messages.apply(pd.Series)\
                        .merge(message, left_index=True, right_index=True)\
                        .drop(['messages'], axis=1)\
                        .melt(value_name='messages')\
                        .drop('variable', axis=1)\
                        .dropna()
            message['index']=[data.index[i]]*message.shape[0]
            message = message.set_index('index')
        
        _preprocess(message)
        if tfidf:
            temp = message.groupby(["index"])["messages"].agg(lambda x: ' '.join(x.astype(str))).to_frame()
            docs = temp.messages.tolist()
            result.append(docs[0])
        else:
            df = df.append(message)

    return result if tfidf else df

# %% [markdown]
# #### 2. Text Encoding
#
# Here we employ the gensim implementation of Word2Vec to encode our logs as fixed length numerical vectors. Logs are noteably not the natural usecase for Word2Vec, but this appraoch attempts to leverage the fact that logs lines themselves, like words, have a context, so encoding a log based on its co-occurence with other logs does make some intuitive sense.

# %%
def create(words, vector_length, window_size):
    """Create new word2vec model."""
    w2vmodel = {}
    for col in words.columns:
        if col in words:
            w2vmodel[col] = gs.models.Word2Vec([list(words[col])], min_count=1, size=vector_length, 
                                     window=window_size, seed=42, workers=1, iter=550,sg=0)
        else:
            #_LOGGER.warning("Skipping key %s as it does not exist in 'words'" % col)
            pass
        
    transformed_data = one_vector(words, w2vmodel)
    transformed_data = transformed_data[:,1:]    
    return w2vmodel, transformed_data

def one_vector(new_D, w2vmodel):
    """Create a single vector from model."""
    transforms = {}
    for col in w2vmodel.keys():
        if col in new_D:
            transforms[col] = w2vmodel[col].wv[new_D[col]]

    new_data = []

    for i in range(len(transforms["messages"])):
        logc = np.array(0)
        for _, c in transforms.items():
            if c.item(i):
                logc = np.append(logc, c[i])
            else:
                logc = np.append(logc, [0, 0, 0, 0, 0])
        new_data.append(logc)

    return np.array(new_data, ndmin=2)

# %% [markdown]
# Function to retrain the Word2Vec model when new log message added, so we can then make an inference about the new log message.

# %%
def get_encode(w2vmodel, log, data):
    train_with_all = False  # Here we train the new log only
    if not train_with_all:
        w2vmodel['messages'].build_vocab([[log]], update=True)
    
    log = pd.DataFrame({"messages":log},index=[1])
    _preprocess(log)
    
    if log.messages.iloc[0] in list(w2vmodel['messages'].wv.vocab.keys()):
        vector = w2vmodel["messages"].wv[log.messages.iloc[0]]
    else:
        data_new = data.append(log, ignore_index=True)
        w2vmodel_new = create(data_new, 100,3)[0]                                
        vector = w2vmodel_new["messages"].wv[log.messages.iloc[0]]
    
    return vector

# %% [markdown]
# Function to employ the sklearn implementation of Tf-idf to encode our logs as numerical vectors.

# %%
def tfidf_encoder(docs):
    
    tfidf_vectorizer=TfidfVectorizer(use_idf=True, lowercase=False)
    tfidf_fit=tfidf_vectorizer.fit(docs)
#     tfidf
    tfidf_transform=tfidf_fit.transform(docs)
    return tfidf_vectorizer, tfidf_transform
#     # idf
#     idf_transform = scipy.sparse.csr_matrix([tfidf_vectorizer.idf_.tolist()] * 56)
#     return tfidf_vectorizer, idf_transform

# %% [markdown]
# #### 3. Model Training
#
# Here we employ the sklearn implementation of the K-means to train our model. This function simply makes it a bit easier for the user to interact with the model. This function returns a trained model, the index of the centroids, the distances from data points to the centroids, and the coordinates of the controids.

# %%
def train_kmeans_model(n_clusters, transformed_data):
    kmeans = KMeans(n_clusters=n_clusters, init='k-means++', n_init= 20, max_iter=300, n_jobs = None, algorithm="auto")
    fit = kmeans.fit(transformed_data)
    index = fit.predict(transformed_data)
    dist = fit.transform(transformed_data)
    clusters = fit.cluster_centers_
    return fit, index, dist, clusters

# %% [markdown]
# #### 4. Generating Anomaly Scores
#
# One of the key elements of this approach is quantifying the distance between our logs and the centroids of the K-means model. The function below performs calculaton for the information of the K-means model needed for model inference / prediction.

# %%
def generate_stats_table(index, dist, clusters):
    n_clusters = clusters.shape[0]
    pd1 = pd.DataFrame(dist, columns = range(n_clusters))
    pd2 = pd.DataFrame(index, columns = ['label'])
    dist_df = pd.concat([pd1, pd2], axis=1)    

    cluster = [None] * n_clusters
    stats = [None] * n_clusters
    for i in range(n_clusters):
        cluster[i] = dist_df[dist_df['label']==i][i].tolist()
        stats[i] = [np.min(cluster[i]),np.max(cluster[i]), 
                    np.mean(cluster[i]), np.std(cluster[i])]

    stats = np.asarray(stats)
    pd_stats = pd.DataFrame(stats, columns = ['min','max','mean','sd'])
    return pd_stats

# %% [markdown]
# #### 5. Model Inference / Prediction
#
# Here we are making an inference about a list of or a single new log message. This is done by scoring the incoming log and evaluating whether or not it passess a certain threshold value.

# %%
def get_anomaly_app_given_sd(multiplier, pd_stats, dist):
    threshold = (multiplier)*pd_stats['sd'].values[0] + pd_stats['mean'].values[0]   
    count = 0
    outliers  = []
    for i, j in enumerate(dist):
        if j > threshold:
            outliers.append(i)
            count += 1
    return outliers, count

# %%
def is_anomaly_w2v(sd_multiplier, log_vector, fit, pd_stats):
    
    clusters = fit.cluster_centers_   
    log_vector = log_vector.reshape(1,len(log_vector))
    index_new = fit.predict(log_vector)
    log_vector = log_vector.reshape(100,)
    dist_new = np.linalg.norm(clusters[index_new]-log_vector)
#     from scipy.stats import normaltest
#     normaltest(cluster[index_new])
#     plot(cluster[index_new])

    threshold = sd_multiplier * pd_stats['sd'].values[index_new[0]] + pd_stats['mean'].values[index_new[0]]   
    
    return dist_new > threshold

# %%
# tfidf
def is_anomaly_tfidf(transformed_data, tfidf_vectorizer, outlier_index, new_log):
    
    unique_log_list = tfidf_vectorizer.get_feature_names()
    if new_log not in unique_log_list: return True

    tfidf_score_table = pd.DataFrame(transformed_data.todense())\
                        .loc[outlier_index].max().reset_index()\
                        .rename({0:'tf-idf score'}, axis=1)

    tfidf_score_table.insert(2, 'log', unique_log_list)

    tfidf_score_table = tfidf_score_table\
                        .sort_values(by=['tf-idf score'], ascending=False)\
                        .drop('index', axis=1).reset_index()

    anomaly_log_list = tfidf_score_table.loc[1:10].log.values.tolist()
    
    return new_log in anomaly_log_list

# %%
# idf
def is_anomaly_tfidf(transformed_data, tfidf_vectorizer, outlier_index, new_log):
    
    unique_log_list = tfidf_vectorizer.get_feature_names()
    if new_log not in unique_log_list: return True
    tfidf_score_table = pd.DataFrame(tfidf_vectorizer.idf_)\
                        .rename({0:'tf-idf score'}, axis=1)
    tfidf_score_table.insert(1, 'log', unique_log_list)
    tfidf_score_table = tfidf_score_table\
                         .sort_values(by=['tf-idf score'], ascending=False)\
                         .reset_index()
    anomaly_log_list = tfidf_score_table.loc[1:10].log.values.tolist()
    
    return new_log in anomaly_log_list

# %%
def show_labels_given_anomaly_log(data, df, anomaly_log):
    anomaly_count = pd.DataFrame()
    for i in range(np.asarray(anomaly_log).shape[0]):
        anomaly_list = np.where(df.messages == anomaly_log[i])[0]
        temp = df.index[anomaly_list].value_counts().to_frame(name='freq')
        anomaly_count = pd.concat([anomaly_count,temp]).groupby(level=0).sum().sort_values('freq', ascending=False)

    label = []
    [label.append(data.loc[anomaly_count.index[i]].label) for i in range(anomaly_count.index.shape[0])]
    anomaly_count['label'] = label
    return anomaly_count

# %% [markdown]
# ### All in One
# Integrate all the steps and functions into the one below, so user can train the model and get inference with one single call. One thing to keep in mind is that the 'tf-idf' encoding method should only be used on 'log' level.

# %%
def lad_with_kmeans(data, encoding_level = 'log', encoding_method = 'w2v', sd = 3, new_log = None):
    assert not(encoding_method == 'tfidf' and encoding_level != 'log'), 'Error, if-idf can only be used on log level!'
    single = new_log is not None
    tfidf = (encoding_method == 'tfidf')
    use_log = (encoding_level == 'log')
    
    if tfidf:
        app_id = data.index.values
        docs = merge_logs_by_unit(data, 'log', tfidf = True)
        tfidf_vectorizer, transformed_data = tfidf_encoder(docs)
    else:
        if single:
            df = data[['messages']]
            df = merge_logs_by_unit(df)
            logs = df.messages.values

            w2vmodel, transformed_data = create(df,100,3)        
        else:
            df = merge_logs_by_unit(data, encoding_level)

            if use_log:
                app_id = df.index.values
                logs = df.messages.values
            else: 
                app_id = data.index.values
                
            transformed_data = create(df, 100,3)[1]  

    n_clusters = 1
    fit, index, dist, clusters = train_kmeans_model(n_clusters, transformed_data)
    pd_stats = generate_stats_table(index, dist, clusters)   
    
    outlier_index, count = get_anomaly_app_given_sd(sd, pd_stats, dist)
    
    if not single:
        if use_log and not tfidf:
            outliers_log = logs[outlier_index]
            outliers_log = pd.DataFrame(outliers_log, columns = ['log'])
            outliers_log = outliers_log['log'].value_counts().to_frame(name='Count')
            anomaly_log_list = outliers_log.index.tolist()

            labels_with_anomaly_freq = show_labels_given_anomaly_log(data, df, anomaly_log_list)
            anomaly_count = int(0.35*labels_with_anomaly_freq.index.shape[0])
            anomaly_table = labels_with_anomaly_freq[['label']].iloc[0:anomaly_count]
        else:
            outliers  = app_id[outlier_index]
            anomaly_count = count
            anomaly_table = data.loc[outliers.tolist(), ['label']]

        return anomaly_count, anomaly_table
    else:
        if tfidf:
            unique_log_list = np.asarray(tfidf_vectorizer.get_feature_names())[outlier_index]

            tfidf_score_table = pd.DataFrame(tfidf_vectorizer.idf_[outlier_index])\
                    .rename({0:'tf-idf score'}, axis=1)
            tfidf_score_table.insert(1, 'log', unique_log_list)
            tfidf_score_table = tfidf_score_table.sort_values(by=['tf-idf score'], ascending=False)\
                    .reset_index()
            anomaly_log_list = tfidf_score_table.loc[1:10].log.values.tolist()        
        else:
            outliers_log = logs[outlier_index]
            outliers_log = pd.DataFrame(outliers_log, columns = ['log'])
            outliers_log = outliers_log['log'].value_counts().to_frame(name='Count')
            anomaly_log_list = outliers_log.index.tolist()
        
        return new_log in anomaly_log_list

# %% [markdown]
# ### Demo

# %% [markdown]
# #### 1. Read in dataset

# %%
data_path = '~/Downloads/evaluation_set.dms'
#data_path = 'C:/Users/martu/Downloads/evaluation_set'
file = open(os.path.expanduser(data_path), 'rb')
data = pickle.load(file)
file.close()

# %%
write_path = '~/Desktop/Redhat_Proj/'
with open('unique_logs.pickle', 'wb') as filehandle:
    pickle.dump(unique_logs, filehandle)

# %% [markdown]
# #### 2. EDA

# %%
x = data.label.value_counts()
for i in x.keys():
    print(i, x[i])
# Out:
# Machine_down 28
# Normal 11
# Disk_full 9
# Network_disconnection 7

# %% [markdown]
# #### 3. Predicting with different data type, encoding scheme, and training methods
# Example: lad_with_kmeans(data, encoding_level = 'application', encoding_method = 'w2v', sd = 0.5, new_log = 'sdfasf')

# %% [markdown]
# Predicting data file with Word2Vec on 'application' level with standard deviation 0.5

# %%
count1, table1 = lad_with_kmeans(data, encoding_level = 'application', encoding_method = 'w2v', sd = 0.5)
# Out:
# collecting all words and their counts
# PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# collected 55 word types from a corpus of 55 raw words and 1 sentences
# Loading a fresh vocabulary
# effective_min_count=1 retains 55 unique words (100% of original 55, drops 0)
# effective_min_count=1 leaves 55 word corpus (100% of original 55, drops 0)
# deleting the raw counts dictionary of 55 items
# sample=0.001 downsamples 55 most-common words
# downsampling leaves estimated 15 word corpus (29.0% of prior 55)
# estimated required memory for 55 words and 100 dimensions: 71500 bytes
# resetting layer weights
# training model with 1 workers on 55 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=3
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 1 : training on 55 raw words (17 effective words) took 0.0s, 7839 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 2 : training on 55 raw words (15 effective words) took 0.0s, 6341 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 3 : training on 55 raw words (14 effective words) took 0.0s, 7266 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 4 : training on 55 raw words (18 effective words) took 0.0s, 7139 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 5 : training on 55 raw words (18 effective words) took 0.0s, 9244 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 6 : training on 55 raw words (19 effective words) took 0.0s, 7449 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 7 : training on 55 raw words (17 effective words) took 0.0s, 23262 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 8 : training on 55 raw words (13 effective words) took 0.0s, 5455 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 9 : training on 55 raw words (11 effective words) took 0.0s, 5764 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 10 : training on 55 raw words (18 effective words) took 0.0s, 7495 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 11 : training on 55 raw words (14 effective words) took 0.0s, 6797 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 12 : training on 55 raw words (21 effective words) took 0.0s, 8104 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 13 : training on 55 raw words (15 effective words) took 0.0s, 5661 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 14 : training on 55 raw words (12 effective words) took 0.0s, 4477 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 15 : training on 55 raw words (20 effective words) took 0.0s, 6935 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 16 : training on 55 raw words (14 effective words) took 0.0s, 5382 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 17 : training on 55 raw words (19 effective words) took 0.0s, 6669 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 18 : training on 55 raw words (14 effective words) took 0.0s, 4462 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 19 : training on 55 raw words (13 effective words) took 0.0s, 5625 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 20 : training on 55 raw words (16 effective words) took 0.0s, 6396 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 21 : training on 55 raw words (15 effective words) took 0.0s, 6050 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 22 : training on 55 raw words (19 effective words) took 0.0s, 7352 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 23 : training on 55 raw words (18 effective words) took 0.0s, 9899 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 24 : training on 55 raw words (13 effective words) took 0.0s, 4270 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 25 : training on 55 raw words (16 effective words) took 0.0s, 6545 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 26 : training on 55 raw words (17 effective words) took 0.0s, 6756 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 27 : training on 55 raw words (14 effective words) took 0.0s, 5912 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 28 : training on 55 raw words (20 effective words) took 0.0s, 7826 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 29 : training on 55 raw words (12 effective words) took 0.0s, 7047 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 30 : training on 55 raw words (18 effective words) took 0.0s, 6931 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 31 : training on 55 raw words (13 effective words) took 0.0s, 6387 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 32 : training on 55 raw words (14 effective words) took 0.0s, 6273 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 33 : training on 55 raw words (18 effective words) took 0.0s, 7250 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 34 : training on 55 raw words (16 effective words) took 0.0s, 5257 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 35 : training on 55 raw words (18 effective words) took 0.0s, 7222 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 36 : training on 55 raw words (18 effective words) took 0.0s, 6315 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 37 : training on 55 raw words (11 effective words) took 0.0s, 3848 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 38 : training on 55 raw words (14 effective words) took 0.0s, 5062 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 39 : training on 55 raw words (17 effective words) took 0.0s, 5642 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 40 : training on 55 raw words (8 effective words) took 0.0s, 2739 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 41 : training on 55 raw words (24 effective words) took 0.0s, 9217 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 42 : training on 55 raw words (16 effective words) took 0.0s, 7037 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 43 : training on 55 raw words (16 effective words) took 0.0s, 6162 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 44 : training on 55 raw words (19 effective words) took 0.0s, 8556 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 45 : training on 55 raw words (15 effective words) took 0.0s, 6607 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 46 : training on 55 raw words (13 effective words) took 0.0s, 4836 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 47 : training on 55 raw words (16 effective words) took 0.0s, 6559 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 48 : training on 55 raw words (20 effective words) took 0.0s, 7472 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 49 : training on 55 raw words (18 effective words) took 0.0s, 7823 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 50 : training on 55 raw words (13 effective words) took 0.0s, 4917 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 51 : training on 55 raw words (24 effective words) took 0.0s, 9035 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 52 : training on 55 raw words (20 effective words) took 0.0s, 7691 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 53 : training on 55 raw words (11 effective words) took 0.0s, 4222 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 54 : training on 55 raw words (13 effective words) took 0.0s, 5361 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 55 : training on 55 raw words (15 effective words) took 0.0s, 5768 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 56 : training on 55 raw words (15 effective words) took 0.0s, 6424 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 57 : training on 55 raw words (16 effective words) took 0.0s, 6049 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 58 : training on 55 raw words (17 effective words) took 0.0s, 6629 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 59 : training on 55 raw words (17 effective words) took 0.0s, 7070 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 60 : training on 55 raw words (13 effective words) took 0.0s, 5099 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 61 : training on 55 raw words (14 effective words) took 0.0s, 5205 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 62 : training on 55 raw words (15 effective words) took 0.0s, 6015 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 63 : training on 55 raw words (15 effective words) took 0.0s, 6315 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 64 : training on 55 raw words (25 effective words) took 0.0s, 10947 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 65 : training on 55 raw words (10 effective words) took 0.0s, 3906 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 66 : training on 55 raw words (15 effective words) took 0.0s, 7274 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 67 : training on 55 raw words (14 effective words) took 0.0s, 4680 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 68 : training on 55 raw words (24 effective words) took 0.0s, 13195 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 69 : training on 55 raw words (16 effective words) took 0.0s, 6241 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 70 : training on 55 raw words (16 effective words) took 0.0s, 9784 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 71 : training on 55 raw words (15 effective words) took 0.0s, 7550 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 72 : training on 55 raw words (16 effective words) took 0.0s, 6463 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 73 : training on 55 raw words (15 effective words) took 0.0s, 6676 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 74 : training on 55 raw words (8 effective words) took 0.0s, 3751 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 75 : training on 55 raw words (11 effective words) took 0.0s, 4738 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 76 : training on 55 raw words (15 effective words) took 0.0s, 6658 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 77 : training on 55 raw words (15 effective words) took 0.0s, 6710 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 78 : training on 55 raw words (14 effective words) took 0.0s, 6776 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 79 : training on 55 raw words (17 effective words) took 0.0s, 7328 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 80 : training on 55 raw words (10 effective words) took 0.0s, 4877 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 81 : training on 55 raw words (16 effective words) took 0.0s, 7125 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 82 : training on 55 raw words (17 effective words) took 0.0s, 6199 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 83 : training on 55 raw words (12 effective words) took 0.0s, 5723 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 84 : training on 55 raw words (17 effective words) took 0.0s, 9372 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 85 : training on 55 raw words (12 effective words) took 0.0s, 5438 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 86 : training on 55 raw words (14 effective words) took 0.0s, 5329 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 87 : training on 55 raw words (15 effective words) took 0.0s, 5937 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 88 : training on 55 raw words (10 effective words) took 0.0s, 5740 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 89 : training on 55 raw words (18 effective words) took 0.0s, 7108 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 90 : training on 55 raw words (11 effective words) took 0.0s, 4846 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 91 : training on 55 raw words (14 effective words) took 0.0s, 6447 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 92 : training on 55 raw words (17 effective words) took 0.0s, 7898 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 93 : training on 55 raw words (8 effective words) took 0.0s, 3446 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 94 : training on 55 raw words (21 effective words) took 0.0s, 8900 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 95 : training on 55 raw words (17 effective words) took 0.0s, 6930 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 96 : training on 55 raw words (16 effective words) took 0.0s, 6158 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 97 : training on 55 raw words (15 effective words) took 0.0s, 5651 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 98 : training on 55 raw words (14 effective words) took 0.0s, 5258 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 99 : training on 55 raw words (11 effective words) took 0.0s, 4789 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 100 : training on 55 raw words (14 effective words) took 0.0s, 5488 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 101 : training on 55 raw words (14 effective words) took 0.0s, 5880 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 102 : training on 55 raw words (9 effective words) took 0.0s, 3734 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 103 : training on 55 raw words (15 effective words) took 0.0s, 6499 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 104 : training on 55 raw words (18 effective words) took 0.0s, 7351 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 105 : training on 55 raw words (17 effective words) took 0.0s, 8429 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 106 : training on 55 raw words (21 effective words) took 0.0s, 8710 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 107 : training on 55 raw words (11 effective words) took 0.0s, 4916 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 108 : training on 55 raw words (14 effective words) took 0.0s, 5760 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 109 : training on 55 raw words (12 effective words) took 0.0s, 4505 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 110 : training on 55 raw words (15 effective words) took 0.0s, 6683 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 111 : training on 55 raw words (13 effective words) took 0.0s, 5254 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 112 : training on 55 raw words (24 effective words) took 0.0s, 10524 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 113 : training on 55 raw words (18 effective words) took 0.0s, 7776 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 114 : training on 55 raw words (15 effective words) took 0.0s, 6609 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 115 : training on 55 raw words (13 effective words) took 0.0s, 5193 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 116 : training on 55 raw words (20 effective words) took 0.0s, 9252 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 117 : training on 55 raw words (15 effective words) took 0.0s, 5976 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 118 : training on 55 raw words (20 effective words) took 0.0s, 8668 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 119 : training on 55 raw words (17 effective words) took 0.0s, 6704 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 120 : training on 55 raw words (16 effective words) took 0.0s, 7641 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 121 : training on 55 raw words (12 effective words) took 0.0s, 4971 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 122 : training on 55 raw words (14 effective words) took 0.0s, 6946 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 123 : training on 55 raw words (13 effective words) took 0.0s, 5039 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 124 : training on 55 raw words (22 effective words) took 0.0s, 9984 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 125 : training on 55 raw words (14 effective words) took 0.0s, 6215 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 126 : training on 55 raw words (13 effective words) took 0.0s, 5340 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 127 : training on 55 raw words (18 effective words) took 0.0s, 6641 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 128 : training on 55 raw words (21 effective words) took 0.0s, 8253 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 129 : training on 55 raw words (15 effective words) took 0.0s, 5963 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 130 : training on 55 raw words (14 effective words) took 0.0s, 5295 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 131 : training on 55 raw words (20 effective words) took 0.0s, 8344 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 132 : training on 55 raw words (13 effective words) took 0.0s, 5242 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 133 : training on 55 raw words (13 effective words) took 0.0s, 5595 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 134 : training on 55 raw words (11 effective words) took 0.0s, 4851 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 135 : training on 55 raw words (16 effective words) took 0.0s, 7868 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 136 : training on 55 raw words (18 effective words) took 0.0s, 8662 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 137 : training on 55 raw words (18 effective words) took 0.0s, 7050 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 138 : training on 55 raw words (22 effective words) took 0.0s, 9819 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 139 : training on 55 raw words (11 effective words) took 0.0s, 4656 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 140 : training on 55 raw words (17 effective words) took 0.0s, 6489 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 141 : training on 55 raw words (17 effective words) took 0.0s, 6922 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 142 : training on 55 raw words (13 effective words) took 0.0s, 6176 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 143 : training on 55 raw words (19 effective words) took 0.0s, 7704 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 144 : training on 55 raw words (18 effective words) took 0.0s, 6969 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 145 : training on 55 raw words (20 effective words) took 0.0s, 9700 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 146 : training on 55 raw words (18 effective words) took 0.0s, 10923 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 147 : training on 55 raw words (19 effective words) took 0.0s, 8007 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 148 : training on 55 raw words (11 effective words) took 0.0s, 4904 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 149 : training on 55 raw words (18 effective words) took 0.0s, 7083 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 150 : training on 55 raw words (18 effective words) took 0.0s, 9252 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 151 : training on 55 raw words (13 effective words) took 0.0s, 6110 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 152 : training on 55 raw words (20 effective words) took 0.0s, 7778 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 153 : training on 55 raw words (17 effective words) took 0.0s, 10190 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 154 : training on 55 raw words (15 effective words) took 0.0s, 5732 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 155 : training on 55 raw words (17 effective words) took 0.0s, 13731 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 156 : training on 55 raw words (16 effective words) took 0.0s, 5875 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 157 : training on 55 raw words (13 effective words) took 0.0s, 4518 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 158 : training on 55 raw words (20 effective words) took 0.0s, 8718 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 159 : training on 55 raw words (15 effective words) took 0.0s, 5736 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 160 : training on 55 raw words (16 effective words) took 0.0s, 7934 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 161 : training on 55 raw words (19 effective words) took 0.0s, 8963 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 162 : training on 55 raw words (14 effective words) took 0.0s, 5482 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 163 : training on 55 raw words (18 effective words) took 0.0s, 9630 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 164 : training on 55 raw words (23 effective words) took 0.0s, 9133 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 165 : training on 55 raw words (14 effective words) took 0.0s, 5298 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 166 : training on 55 raw words (17 effective words) took 0.0s, 7173 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 167 : training on 55 raw words (14 effective words) took 0.0s, 7221 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 168 : training on 55 raw words (17 effective words) took 0.0s, 7752 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 169 : training on 55 raw words (17 effective words) took 0.0s, 8366 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 170 : training on 55 raw words (19 effective words) took 0.0s, 11294 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 171 : training on 55 raw words (14 effective words) took 0.0s, 5348 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 172 : training on 55 raw words (13 effective words) took 0.0s, 5979 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 173 : training on 55 raw words (18 effective words) took 0.0s, 7506 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 174 : training on 55 raw words (25 effective words) took 0.0s, 10893 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 175 : training on 55 raw words (17 effective words) took 0.0s, 8624 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 176 : training on 55 raw words (14 effective words) took 0.0s, 5829 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 177 : training on 55 raw words (16 effective words) took 0.0s, 6444 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 178 : training on 55 raw words (18 effective words) took 0.0s, 7911 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 179 : training on 55 raw words (13 effective words) took 0.0s, 6029 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 180 : training on 55 raw words (15 effective words) took 0.0s, 6480 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 181 : training on 55 raw words (17 effective words) took 0.0s, 10210 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 182 : training on 55 raw words (18 effective words) took 0.0s, 7228 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 183 : training on 55 raw words (14 effective words) took 0.0s, 6749 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 184 : training on 55 raw words (17 effective words) took 0.0s, 7872 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 185 : training on 55 raw words (18 effective words) took 0.0s, 6547 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 186 : training on 55 raw words (11 effective words) took 0.0s, 4656 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 187 : training on 55 raw words (21 effective words) took 0.0s, 7974 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 188 : training on 55 raw words (19 effective words) took 0.0s, 8119 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 189 : training on 55 raw words (18 effective words) took 0.0s, 8027 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 190 : training on 55 raw words (13 effective words) took 0.0s, 6764 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 191 : training on 55 raw words (19 effective words) took 0.0s, 8834 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 192 : training on 55 raw words (15 effective words) took 0.0s, 6922 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 193 : training on 55 raw words (13 effective words) took 0.0s, 5670 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 194 : training on 55 raw words (20 effective words) took 0.0s, 8087 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 195 : training on 55 raw words (16 effective words) took 0.0s, 7495 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 196 : training on 55 raw words (15 effective words) took 0.0s, 5450 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 197 : training on 55 raw words (17 effective words) took 0.0s, 8157 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 198 : training on 55 raw words (20 effective words) took 0.0s, 8479 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 199 : training on 55 raw words (15 effective words) took 0.0s, 6890 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 200 : training on 55 raw words (14 effective words) took 0.0s, 5781 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 201 : training on 55 raw words (13 effective words) took 0.0s, 6886 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 202 : training on 55 raw words (21 effective words) took 0.0s, 8964 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 203 : training on 55 raw words (16 effective words) took 0.0s, 7698 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 204 : training on 55 raw words (16 effective words) took 0.0s, 8277 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 205 : training on 55 raw words (17 effective words) took 0.0s, 7748 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 206 : training on 55 raw words (13 effective words) took 0.0s, 4656 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 207 : training on 55 raw words (13 effective words) took 0.0s, 5236 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 208 : training on 55 raw words (9 effective words) took 0.0s, 3955 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 209 : training on 55 raw words (20 effective words) took 0.0s, 11129 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 210 : training on 55 raw words (12 effective words) took 0.0s, 6783 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 211 : training on 55 raw words (19 effective words) took 0.0s, 7627 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 212 : training on 55 raw words (13 effective words) took 0.0s, 5682 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 213 : training on 55 raw words (14 effective words) took 0.0s, 7529 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 214 : training on 55 raw words (13 effective words) took 0.0s, 6165 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 215 : training on 55 raw words (16 effective words) took 0.0s, 5691 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 216 : training on 55 raw words (12 effective words) took 0.0s, 4949 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 217 : training on 55 raw words (17 effective words) took 0.0s, 6868 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 218 : training on 55 raw words (15 effective words) took 0.0s, 6011 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 219 : training on 55 raw words (19 effective words) took 0.0s, 8304 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# ...
# EPOCH - 477 : training on 55 raw words (22 effective words) took 0.0s, 10695 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 478 : training on 55 raw words (15 effective words) took 0.0s, 5843 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 479 : training on 55 raw words (15 effective words) took 0.0s, 7420 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 480 : training on 55 raw words (18 effective words) took 0.0s, 7768 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 481 : training on 55 raw words (17 effective words) took 0.0s, 7066 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 482 : training on 55 raw words (14 effective words) took 0.0s, 5664 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 483 : training on 55 raw words (12 effective words) took 0.0s, 6330 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 484 : training on 55 raw words (16 effective words) took 0.0s, 7727 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 485 : training on 55 raw words (17 effective words) took 0.0s, 7331 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 486 : training on 55 raw words (15 effective words) took 0.0s, 9151 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 487 : training on 55 raw words (26 effective words) took 0.0s, 10683 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 488 : training on 55 raw words (21 effective words) took 0.0s, 9858 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 489 : training on 55 raw words (8 effective words) took 0.0s, 3195 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 490 : training on 55 raw words (15 effective words) took 0.0s, 8159 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 491 : training on 55 raw words (15 effective words) took 0.0s, 6928 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 492 : training on 55 raw words (12 effective words) took 0.0s, 4758 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 493 : training on 55 raw words (13 effective words) took 0.0s, 6613 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 494 : training on 55 raw words (18 effective words) took 0.0s, 6419 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 495 : training on 55 raw words (14 effective words) took 0.0s, 6183 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 496 : training on 55 raw words (15 effective words) took 0.0s, 6251 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 497 : training on 55 raw words (14 effective words) took 0.0s, 6614 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 498 : training on 55 raw words (14 effective words) took 0.0s, 5848 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 499 : training on 55 raw words (15 effective words) took 0.0s, 5308 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 500 : training on 55 raw words (18 effective words) took 0.0s, 7990 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 501 : training on 55 raw words (16 effective words) took 0.0s, 5852 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 502 : training on 55 raw words (17 effective words) took 0.0s, 5937 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 503 : training on 55 raw words (20 effective words) took 0.0s, 7767 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 504 : training on 55 raw words (21 effective words) took 0.0s, 8792 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 505 : training on 55 raw words (16 effective words) took 0.0s, 6472 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 506 : training on 55 raw words (18 effective words) took 0.0s, 11343 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 507 : training on 55 raw words (14 effective words) took 0.0s, 5375 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 508 : training on 55 raw words (17 effective words) took 0.0s, 11324 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 509 : training on 55 raw words (20 effective words) took 0.0s, 8326 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 510 : training on 55 raw words (22 effective words) took 0.0s, 9508 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 511 : training on 55 raw words (17 effective words) took 0.0s, 6892 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 512 : training on 55 raw words (21 effective words) took 0.0s, 9236 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 513 : training on 55 raw words (24 effective words) took 0.0s, 8997 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 514 : training on 55 raw words (18 effective words) took 0.0s, 9012 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 515 : training on 55 raw words (18 effective words) took 0.0s, 7245 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 516 : training on 55 raw words (11 effective words) took 0.0s, 4803 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 517 : training on 55 raw words (11 effective words) took 0.0s, 4889 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 518 : training on 55 raw words (15 effective words) took 0.0s, 8612 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 519 : training on 55 raw words (19 effective words) took 0.0s, 8007 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 520 : training on 55 raw words (18 effective words) took 0.0s, 8303 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 521 : training on 55 raw words (16 effective words) took 0.0s, 6220 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 522 : training on 55 raw words (14 effective words) took 0.0s, 6090 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 523 : training on 55 raw words (21 effective words) took 0.0s, 8803 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 524 : training on 55 raw words (13 effective words) took 0.0s, 5482 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 525 : training on 55 raw words (19 effective words) took 0.0s, 8862 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 526 : training on 55 raw words (16 effective words) took 0.0s, 6710 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 527 : training on 55 raw words (16 effective words) took 0.0s, 6317 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 528 : training on 55 raw words (16 effective words) took 0.0s, 6341 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 529 : training on 55 raw words (16 effective words) took 0.0s, 7360 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 530 : training on 55 raw words (10 effective words) took 0.0s, 5028 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 531 : training on 55 raw words (23 effective words) took 0.0s, 7858 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 532 : training on 55 raw words (12 effective words) took 0.0s, 5967 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 533 : training on 55 raw words (15 effective words) took 0.0s, 8541 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 534 : training on 55 raw words (17 effective words) took 0.0s, 7619 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 535 : training on 55 raw words (11 effective words) took 0.0s, 4763 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 536 : training on 55 raw words (18 effective words) took 0.0s, 6659 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 537 : training on 55 raw words (16 effective words) took 0.0s, 7588 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 538 : training on 55 raw words (12 effective words) took 0.0s, 4755 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 539 : training on 55 raw words (17 effective words) took 0.0s, 8016 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 540 : training on 55 raw words (17 effective words) took 0.0s, 7085 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 541 : training on 55 raw words (14 effective words) took 0.0s, 5858 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 542 : training on 55 raw words (19 effective words) took 0.0s, 7482 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 543 : training on 55 raw words (10 effective words) took 0.0s, 4472 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 544 : training on 55 raw words (10 effective words) took 0.0s, 4657 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 545 : training on 55 raw words (16 effective words) took 0.0s, 8431 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 546 : training on 55 raw words (15 effective words) took 0.0s, 7432 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 547 : training on 55 raw words (14 effective words) took 0.0s, 5359 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 548 : training on 55 raw words (11 effective words) took 0.0s, 4690 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 549 : training on 55 raw words (17 effective words) took 0.0s, 6616 effective words/s
# job loop exiting, total 1 jobs
# worker exiting, processed 1 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 550 : training on 55 raw words (13 effective words) took 0.0s, 5524 effective words/s
# training on a 30250 raw words (8697 effective words) took 2.3s, 3810 effective words/s

# %%
print('Total number of identified anomaly logs: '+'\033[1m'+str(count1)+'\033[0m')
display(table1)
# Out:
# Total number of identified anomaly logs: 12
#                                                 label
# application_1445087491445_0002           Machine_down
# application_1445144423722_0022  Network_disconnection
# application_1445182159119_0014              Disk_full
# application_1445062781478_0012           Machine_down
# application_1445087491445_0010           Machine_down
# application_1445076437777_0001           Machine_down
# application_1445094324383_0004           Machine_down
# application_1445182159119_0012                 Normal
# application_1445062781478_0011                 Normal
# application_1445087491445_0001           Machine_down
# application_1445144423722_0021                 Normal
# application_1445182159119_0013              Disk_full

# %% [markdown]
# Predicting data file with Word2Vec on 'log' level with standard deviation 3

# %%
count2, table2 = lad_with_kmeans(data, encoding_level = 'log', encoding_method = 'w2v', sd = 3)
# Out:
# collecting all words and their counts
# PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# collected 1203 word types from a corpus of 394310 raw words and 1 sentences
# Loading a fresh vocabulary
# effective_min_count=1 retains 1203 unique words (100% of original 1203, drops 0)
# effective_min_count=1 leaves 394310 word corpus (100% of original 394310, drops 0)
# deleting the raw counts dictionary of 1203 items
# sample=0.001 downsamples 46 most-common words
# downsampling leaves estimated 169640 word corpus (43.0% of prior 394310)
# estimated required memory for 1203 words and 100 dimensions: 1563900 bytes
# resetting layer weights
# training model with 1 workers on 1203 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=3
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 1 : training on 394310 raw words (10000 effective words) took 0.0s, 1021613 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 2 : training on 394310 raw words (10000 effective words) took 0.0s, 687531 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 3 : training on 394310 raw words (10000 effective words) took 0.0s, 629066 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 4 : training on 394310 raw words (10000 effective words) took 0.0s, 736347 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 5 : training on 394310 raw words (10000 effective words) took 0.0s, 612757 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 6 : training on 394310 raw words (10000 effective words) took 0.0s, 617119 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 7 : training on 394310 raw words (10000 effective words) took 0.0s, 622175 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 8 : training on 394310 raw words (10000 effective words) took 0.0s, 621618 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 9 : training on 394310 raw words (10000 effective words) took 0.0s, 610970 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 10 : training on 394310 raw words (10000 effective words) took 0.0s, 633772 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 11 : training on 394310 raw words (10000 effective words) took 0.0s, 612767 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 12 : training on 394310 raw words (10000 effective words) took 0.0s, 761546 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 13 : training on 394310 raw words (10000 effective words) took 0.0s, 654913 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 14 : training on 394310 raw words (10000 effective words) took 0.0s, 606598 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 15 : training on 394310 raw words (10000 effective words) took 0.0s, 654191 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 16 : training on 394310 raw words (10000 effective words) took 0.0s, 962193 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 17 : training on 394310 raw words (10000 effective words) took 0.0s, 612637 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 18 : training on 394310 raw words (10000 effective words) took 0.0s, 638388 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 19 : training on 394310 raw words (10000 effective words) took 0.0s, 644103 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 20 : training on 394310 raw words (10000 effective words) took 0.0s, 952574 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 21 : training on 394310 raw words (10000 effective words) took 0.0s, 606498 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 22 : training on 394310 raw words (10000 effective words) took 0.0s, 776894 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 23 : training on 394310 raw words (10000 effective words) took 0.0s, 615434 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 24 : training on 394310 raw words (10000 effective words) took 0.0s, 620268 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 25 : training on 394310 raw words (10000 effective words) took 0.0s, 621765 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 26 : training on 394310 raw words (10000 effective words) took 0.0s, 600846 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 27 : training on 394310 raw words (10000 effective words) took 0.0s, 632041 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 28 : training on 394310 raw words (10000 effective words) took 0.0s, 635855 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 29 : training on 394310 raw words (10000 effective words) took 0.0s, 616267 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 30 : training on 394310 raw words (10000 effective words) took 0.0s, 650216 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 31 : training on 394310 raw words (10000 effective words) took 0.0s, 649700 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 32 : training on 394310 raw words (10000 effective words) took 0.0s, 909516 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 33 : training on 394310 raw words (10000 effective words) took 0.0s, 627158 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 34 : training on 394310 raw words (10000 effective words) took 0.0s, 646969 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 35 : training on 394310 raw words (10000 effective words) took 0.0s, 648371 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 36 : training on 394310 raw words (10000 effective words) took 0.0s, 653419 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 37 : training on 394310 raw words (10000 effective words) took 0.0s, 968920 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 38 : training on 394310 raw words (10000 effective words) took 0.0s, 677667 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 39 : training on 394310 raw words (10000 effective words) took 0.0s, 1025699 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 40 : training on 394310 raw words (10000 effective words) took 0.0s, 717067 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 41 : training on 394310 raw words (10000 effective words) took 0.0s, 960802 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 42 : training on 394310 raw words (10000 effective words) took 0.0s, 762040 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 43 : training on 394310 raw words (10000 effective words) took 0.0s, 731104 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 44 : training on 394310 raw words (10000 effective words) took 0.0s, 759735 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 45 : training on 394310 raw words (10000 effective words) took 0.0s, 764139 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 46 : training on 394310 raw words (10000 effective words) took 0.0s, 786762 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 47 : training on 394310 raw words (10000 effective words) took 0.0s, 778232 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 48 : training on 394310 raw words (10000 effective words) took 0.0s, 744722 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 49 : training on 394310 raw words (10000 effective words) took 0.0s, 963070 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 50 : training on 394310 raw words (10000 effective words) took 0.0s, 707358 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 51 : training on 394310 raw words (10000 effective words) took 0.0s, 765725 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 52 : training on 394310 raw words (10000 effective words) took 0.0s, 754327 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 53 : training on 394310 raw words (10000 effective words) took 0.0s, 751840 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 54 : training on 394310 raw words (10000 effective words) took 0.0s, 755641 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 55 : training on 394310 raw words (10000 effective words) took 0.0s, 697344 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 56 : training on 394310 raw words (10000 effective words) took 0.0s, 722842 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 57 : training on 394310 raw words (10000 effective words) took 0.0s, 719220 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 58 : training on 394310 raw words (10000 effective words) took 0.0s, 711813 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 59 : training on 394310 raw words (10000 effective words) took 0.0s, 707966 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 60 : training on 394310 raw words (10000 effective words) took 0.0s, 690147 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 61 : training on 394310 raw words (10000 effective words) took 0.0s, 854242 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 62 : training on 394310 raw words (10000 effective words) took 0.0s, 658301 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 63 : training on 394310 raw words (10000 effective words) took 0.0s, 653913 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 64 : training on 394310 raw words (10000 effective words) took 0.0s, 1026426 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 65 : training on 394310 raw words (10000 effective words) took 0.0s, 635598 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 66 : training on 394310 raw words (10000 effective words) took 0.0s, 686577 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 67 : training on 394310 raw words (10000 effective words) took 0.0s, 641680 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 68 : training on 394310 raw words (10000 effective words) took 0.0s, 666233 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 69 : training on 394310 raw words (10000 effective words) took 0.0s, 640862 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 70 : training on 394310 raw words (10000 effective words) took 0.0s, 665662 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 71 : training on 394310 raw words (10000 effective words) took 0.0s, 850376 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 72 : training on 394310 raw words (10000 effective words) took 0.0s, 1009964 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 73 : training on 394310 raw words (10000 effective words) took 0.0s, 652698 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 74 : training on 394310 raw words (10000 effective words) took 0.0s, 875317 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 75 : training on 394310 raw words (10000 effective words) took 0.0s, 664056 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 76 : training on 394310 raw words (10000 effective words) took 0.0s, 687438 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 77 : training on 394310 raw words (10000 effective words) took 0.0s, 703491 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 78 : training on 394310 raw words (10000 effective words) took 0.0s, 1031456 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 79 : training on 394310 raw words (10000 effective words) took 0.0s, 680374 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 80 : training on 394310 raw words (10000 effective words) took 0.0s, 668460 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 81 : training on 394310 raw words (10000 effective words) took 0.0s, 690398 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 82 : training on 394310 raw words (10000 effective words) took 0.0s, 890286 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 83 : training on 394310 raw words (10000 effective words) took 0.0s, 638279 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 84 : training on 394310 raw words (10000 effective words) took 0.0s, 987936 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 85 : training on 394310 raw words (10000 effective words) took 0.0s, 667056 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 86 : training on 394310 raw words (10000 effective words) took 0.0s, 642786 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 87 : training on 394310 raw words (10000 effective words) took 0.0s, 646828 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 88 : training on 394310 raw words (10000 effective words) took 0.0s, 655813 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 89 : training on 394310 raw words (10000 effective words) took 0.0s, 703334 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 90 : training on 394310 raw words (10000 effective words) took 0.0s, 729774 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 91 : training on 394310 raw words (10000 effective words) took 0.0s, 723533 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 92 : training on 394310 raw words (10000 effective words) took 0.0s, 759916 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 93 : training on 394310 raw words (10000 effective words) took 0.0s, 717435 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 94 : training on 394310 raw words (10000 effective words) took 0.0s, 745741 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 95 : training on 394310 raw words (10000 effective words) took 0.0s, 781019 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 96 : training on 394310 raw words (10000 effective words) took 0.0s, 774308 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 97 : training on 394310 raw words (10000 effective words) took 0.0s, 769177 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 98 : training on 394310 raw words (10000 effective words) took 0.0s, 759432 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 99 : training on 394310 raw words (10000 effective words) took 0.0s, 710238 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 100 : training on 394310 raw words (10000 effective words) took 0.0s, 734367 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 101 : training on 394310 raw words (10000 effective words) took 0.0s, 763559 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 102 : training on 394310 raw words (10000 effective words) took 0.0s, 1101511 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 103 : training on 394310 raw words (10000 effective words) took 0.0s, 972578 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 104 : training on 394310 raw words (10000 effective words) took 0.0s, 935210 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 105 : training on 394310 raw words (10000 effective words) took 0.0s, 936076 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 106 : training on 394310 raw words (10000 effective words) took 0.0s, 609723 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 107 : training on 394310 raw words (10000 effective words) took 0.0s, 588390 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 108 : training on 394310 raw words (10000 effective words) took 0.0s, 754225 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 109 : training on 394310 raw words (10000 effective words) took 0.0s, 605538 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 110 : training on 394310 raw words (10000 effective words) took 0.0s, 604129 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 111 : training on 394310 raw words (10000 effective words) took 0.0s, 625745 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 112 : training on 394310 raw words (10000 effective words) took 0.0s, 582607 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 113 : training on 394310 raw words (10000 effective words) took 0.0s, 592360 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 114 : training on 394310 raw words (10000 effective words) took 0.0s, 777834 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 115 : training on 394310 raw words (10000 effective words) took 0.0s, 593556 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 116 : training on 394310 raw words (10000 effective words) took 0.0s, 1059485 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 117 : training on 394310 raw words (10000 effective words) took 0.0s, 664588 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 118 : training on 394310 raw words (10000 effective words) took 0.0s, 688340 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 119 : training on 394310 raw words (10000 effective words) took 0.0s, 719541 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 120 : training on 394310 raw words (10000 effective words) took 0.0s, 712882 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 121 : training on 394310 raw words (10000 effective words) took 0.0s, 743915 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 122 : training on 394310 raw words (10000 effective words) took 0.0s, 719091 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 123 : training on 394310 raw words (10000 effective words) took 0.0s, 933010 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 124 : training on 394310 raw words (10000 effective words) took 0.0s, 763030 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 125 : training on 394310 raw words (10000 effective words) took 0.0s, 770637 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 126 : training on 394310 raw words (10000 effective words) took 0.0s, 771885 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 127 : training on 394310 raw words (10000 effective words) took 0.0s, 1078299 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 128 : training on 394310 raw words (10000 effective words) took 0.0s, 673523 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 129 : training on 394310 raw words (10000 effective words) took 0.0s, 588308 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 130 : training on 394310 raw words (10000 effective words) took 0.0s, 637383 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 131 : training on 394310 raw words (10000 effective words) took 0.0s, 647435 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 132 : training on 394310 raw words (10000 effective words) took 0.0s, 653954 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 133 : training on 394310 raw words (10000 effective words) took 0.0s, 914160 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 134 : training on 394310 raw words (10000 effective words) took 0.0s, 681607 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 135 : training on 394310 raw words (10000 effective words) took 0.0s, 728423 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 136 : training on 394310 raw words (10000 effective words) took 0.0s, 740606 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 137 : training on 394310 raw words (10000 effective words) took 0.0s, 953107 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 138 : training on 394310 raw words (10000 effective words) took 0.0s, 724130 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 139 : training on 394310 raw words (10000 effective words) took 0.0s, 710999 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 140 : training on 394310 raw words (10000 effective words) took 0.0s, 731795 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 141 : training on 394310 raw words (10000 effective words) took 0.0s, 1041545 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 142 : training on 394310 raw words (10000 effective words) took 0.0s, 699353 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 143 : training on 394310 raw words (10000 effective words) took 0.0s, 912539 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 144 : training on 394310 raw words (10000 effective words) took 0.0s, 1043785 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 145 : training on 394310 raw words (10000 effective words) took 0.0s, 663474 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 146 : training on 394310 raw words (10000 effective words) took 0.0s, 708634 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 147 : training on 394310 raw words (10000 effective words) took 0.0s, 671071 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 148 : training on 394310 raw words (10000 effective words) took 0.0s, 688626 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 149 : training on 394310 raw words (10000 effective words) took 0.0s, 714434 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 150 : training on 394310 raw words (10000 effective words) took 0.0s, 952938 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 151 : training on 394310 raw words (10000 effective words) took 0.0s, 893917 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 152 : training on 394310 raw words (10000 effective words) took 0.0s, 706804 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 153 : training on 394310 raw words (10000 effective words) took 0.0s, 725866 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 154 : training on 394310 raw words (10000 effective words) took 0.0s, 1003319 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 155 : training on 394310 raw words (10000 effective words) took 0.0s, 743818 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 156 : training on 394310 raw words (10000 effective words) took 0.0s, 753479 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 157 : training on 394310 raw words (10000 effective words) took 0.0s, 961983 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 158 : training on 394310 raw words (10000 effective words) took 0.0s, 723233 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 159 : training on 394310 raw words (10000 effective words) took 0.0s, 736791 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 160 : training on 394310 raw words (10000 effective words) took 0.0s, 995649 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 161 : training on 394310 raw words (10000 effective words) took 0.0s, 786718 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 162 : training on 394310 raw words (10000 effective words) took 0.0s, 780385 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 163 : training on 394310 raw words (10000 effective words) took 0.0s, 981805 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 164 : training on 394310 raw words (10000 effective words) took 0.0s, 1055591 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 165 : training on 394310 raw words (10000 effective words) took 0.0s, 711613 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 166 : training on 394310 raw words (10000 effective words) took 0.0s, 622576 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 167 : training on 394310 raw words (10000 effective words) took 0.0s, 640692 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 168 : training on 394310 raw words (10000 effective words) took 0.0s, 663312 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 169 : training on 394310 raw words (10000 effective words) took 0.0s, 647037 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 170 : training on 394310 raw words (10000 effective words) took 0.0s, 704301 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 171 : training on 394310 raw words (10000 effective words) took 0.0s, 986559 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 172 : training on 394310 raw words (10000 effective words) took 0.0s, 751051 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 173 : training on 394310 raw words (10000 effective words) took 0.0s, 688718 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 174 : training on 394310 raw words (10000 effective words) took 0.0s, 912853 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 175 : training on 394310 raw words (10000 effective words) took 0.0s, 961731 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 176 : training on 394310 raw words (10000 effective words) took 0.0s, 748155 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 177 : training on 394310 raw words (10000 effective words) took 0.0s, 974312 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 178 : training on 394310 raw words (10000 effective words) took 0.0s, 559401 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 179 : training on 394310 raw words (10000 effective words) took 0.0s, 647344 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 180 : training on 394310 raw words (10000 effective words) took 0.0s, 681706 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 181 : training on 394310 raw words (10000 effective words) took 0.0s, 1156280 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 182 : training on 394310 raw words (10000 effective words) took 0.0s, 740753 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 183 : training on 394310 raw words (10000 effective words) took 0.0s, 740218 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 184 : training on 394310 raw words (10000 effective words) took 0.0s, 686324 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 185 : training on 394310 raw words (10000 effective words) took 0.0s, 987419 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 186 : training on 394310 raw words (10000 effective words) took 0.0s, 741967 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 187 : training on 394310 raw words (10000 effective words) took 0.0s, 742407 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 188 : training on 394310 raw words (10000 effective words) took 0.0s, 785979 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 189 : training on 394310 raw words (10000 effective words) took 0.0s, 672601 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 190 : training on 394310 raw words (10000 effective words) took 0.0s, 898994 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 191 : training on 394310 raw words (10000 effective words) took 0.0s, 690358 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 192 : training on 394310 raw words (10000 effective words) took 0.0s, 671860 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 193 : training on 394310 raw words (10000 effective words) took 0.0s, 686273 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 194 : training on 394310 raw words (10000 effective words) took 0.0s, 682339 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 195 : training on 394310 raw words (10000 effective words) took 0.0s, 700152 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 196 : training on 394310 raw words (10000 effective words) took 0.0s, 748150 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 197 : training on 394310 raw words (10000 effective words) took 0.0s, 645906 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 198 : training on 394310 raw words (10000 effective words) took 0.0s, 676469 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 199 : training on 394310 raw words (10000 effective words) took 0.0s, 714073 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 200 : training on 394310 raw words (10000 effective words) took 0.0s, 648360 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 201 : training on 394310 raw words (10000 effective words) took 0.0s, 589469 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 202 : training on 394310 raw words (10000 effective words) took 0.0s, 666666 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 203 : training on 394310 raw words (10000 effective words) took 0.0s, 854912 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 204 : training on 394310 raw words (10000 effective words) took 0.0s, 689255 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 205 : training on 394310 raw words (10000 effective words) took 0.0s, 688801 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 206 : training on 394310 raw words (10000 effective words) took 0.0s, 704103 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 207 : training on 394310 raw words (10000 effective words) took 0.0s, 680229 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 208 : training on 394310 raw words (10000 effective words) took 0.0s, 998457 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 209 : training on 394310 raw words (10000 effective words) took 0.0s, 669855 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 210 : training on 394310 raw words (10000 effective words) took 0.0s, 679060 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# ...
# EPOCH - 480 : training on 394310 raw words (10000 effective words) took 0.0s, 769991 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 481 : training on 394310 raw words (10000 effective words) took 0.0s, 765473 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 482 : training on 394310 raw words (10000 effective words) took 0.0s, 1171017 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 483 : training on 394310 raw words (10000 effective words) took 0.0s, 981144 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 484 : training on 394310 raw words (10000 effective words) took 0.0s, 755936 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 485 : training on 394310 raw words (10000 effective words) took 0.0s, 805417 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 486 : training on 394310 raw words (10000 effective words) took 0.0s, 763485 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 487 : training on 394310 raw words (10000 effective words) took 0.0s, 1166161 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 488 : training on 394310 raw words (10000 effective words) took 0.0s, 794250 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 489 : training on 394310 raw words (10000 effective words) took 0.0s, 1144797 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 490 : training on 394310 raw words (10000 effective words) took 0.0s, 1002703 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 491 : training on 394310 raw words (10000 effective words) took 0.0s, 1030016 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 492 : training on 394310 raw words (10000 effective words) took 0.0s, 763243 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 493 : training on 394310 raw words (10000 effective words) took 0.0s, 783931 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 494 : training on 394310 raw words (10000 effective words) took 0.0s, 1008246 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 495 : training on 394310 raw words (10000 effective words) took 0.0s, 790981 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 496 : training on 394310 raw words (10000 effective words) took 0.0s, 1009438 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 497 : training on 394310 raw words (10000 effective words) took 0.0s, 782142 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 498 : training on 394310 raw words (10000 effective words) took 0.0s, 749598 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 499 : training on 394310 raw words (10000 effective words) took 0.0s, 742424 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 500 : training on 394310 raw words (10000 effective words) took 0.0s, 1014916 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 501 : training on 394310 raw words (10000 effective words) took 0.0s, 791300 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 502 : training on 394310 raw words (10000 effective words) took 0.0s, 1140878 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 503 : training on 394310 raw words (10000 effective words) took 0.0s, 740962 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 504 : training on 394310 raw words (10000 effective words) took 0.0s, 1141707 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 505 : training on 394310 raw words (10000 effective words) took 0.0s, 783154 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 506 : training on 394310 raw words (10000 effective words) took 0.0s, 785113 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 507 : training on 394310 raw words (10000 effective words) took 0.0s, 760581 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 508 : training on 394310 raw words (10000 effective words) took 0.0s, 787239 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 509 : training on 394310 raw words (10000 effective words) took 0.0s, 726300 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 510 : training on 394310 raw words (10000 effective words) took 0.0s, 771201 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 511 : training on 394310 raw words (10000 effective words) took 0.0s, 1185581 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 512 : training on 394310 raw words (10000 effective words) took 0.0s, 745545 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 513 : training on 394310 raw words (10000 effective words) took 0.0s, 732801 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 514 : training on 394310 raw words (10000 effective words) took 0.0s, 757070 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 515 : training on 394310 raw words (10000 effective words) took 0.0s, 1019458 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 516 : training on 394310 raw words (10000 effective words) took 0.0s, 816948 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 517 : training on 394310 raw words (10000 effective words) took 0.0s, 759815 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 518 : training on 394310 raw words (10000 effective words) took 0.0s, 759379 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 519 : training on 394310 raw words (10000 effective words) took 0.0s, 769243 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 520 : training on 394310 raw words (10000 effective words) took 0.0s, 776322 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 521 : training on 394310 raw words (10000 effective words) took 0.0s, 742387 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 522 : training on 394310 raw words (10000 effective words) took 0.0s, 1003005 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 523 : training on 394310 raw words (10000 effective words) took 0.0s, 1099801 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 524 : training on 394310 raw words (10000 effective words) took 0.0s, 707572 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 525 : training on 394310 raw words (10000 effective words) took 0.0s, 683945 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 526 : training on 394310 raw words (10000 effective words) took 0.0s, 722980 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 527 : training on 394310 raw words (10000 effective words) took 0.0s, 634310 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 528 : training on 394310 raw words (10000 effective words) took 0.0s, 689115 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 529 : training on 394310 raw words (10000 effective words) took 0.0s, 708120 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 530 : training on 394310 raw words (10000 effective words) took 0.0s, 723940 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 531 : training on 394310 raw words (10000 effective words) took 0.0s, 683198 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 532 : training on 394310 raw words (10000 effective words) took 0.0s, 704357 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 533 : training on 394310 raw words (10000 effective words) took 0.0s, 698459 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 534 : training on 394310 raw words (10000 effective words) took 0.0s, 684513 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 535 : training on 394310 raw words (10000 effective words) took 0.0s, 1087926 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 536 : training on 394310 raw words (10000 effective words) took 0.0s, 684685 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 537 : training on 394310 raw words (10000 effective words) took 0.0s, 671662 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 538 : training on 394310 raw words (10000 effective words) took 0.0s, 687526 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 539 : training on 394310 raw words (10000 effective words) took 0.0s, 691088 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 540 : training on 394310 raw words (10000 effective words) took 0.0s, 656776 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 541 : training on 394310 raw words (10000 effective words) took 0.0s, 665761 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 542 : training on 394310 raw words (10000 effective words) took 0.0s, 645840 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 543 : training on 394310 raw words (10000 effective words) took 0.0s, 692634 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 544 : training on 394310 raw words (10000 effective words) took 0.0s, 653716 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 545 : training on 394310 raw words (10000 effective words) took 0.0s, 699930 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 546 : training on 394310 raw words (10000 effective words) took 0.0s, 668414 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 547 : training on 394310 raw words (10000 effective words) took 0.0s, 677959 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 548 : training on 394310 raw words (10000 effective words) took 0.0s, 926223 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 549 : training on 394310 raw words (10000 effective words) took 0.0s, 718210 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 550 : training on 394310 raw words (10000 effective words) took 0.0s, 692169 effective words/s
# training on a 216870500 raw words (5500000 effective words) took 8.5s, 645644 effective words/s

# %%
print('Total number of identified anomaly logs: '+'\033[1m'+str(count2)+'\033[0m')
display(table2)
# Out:
# Total number of identified anomaly logs: 19
#                                                 label
# application_1445144423722_0020  Network_disconnection
# application_1445087491445_0004           Machine_down
# application_1445087491445_0005                 Normal
# application_1445062781478_0013           Machine_down
# application_1445087491445_0001           Machine_down
# application_1445087491445_0003           Machine_down
# application_1445087491445_0002           Machine_down
# application_1445094324383_0005           Machine_down
# application_1445062781478_0018           Machine_down
# application_1445182159119_0002              Disk_full
# application_1445087491445_0010           Machine_down
# application_1445144423722_0023  Network_disconnection
# application_1445182159119_0015              Disk_full
# application_1445182159119_0014              Disk_full
# application_1445175094696_0003  Network_disconnection
# application_1445087491445_0009           Machine_down
# application_1445182159119_0018           Machine_down
# application_1445094324383_0004           Machine_down
# application_1445182159119_0004              Disk_full

# %% [markdown]
# Predicting data file with Tf-idf on 'log' level with standard deviation 0.1

# %%
count3, table3 = lad_with_kmeans(data, encoding_level = 'log', encoding_method = 'tfidf', sd = 0.1)

# %%
print('Total number of identified anomaly logs: '+'\033[1m'+str(count3)+'\033[0m')
display(table3)
# Out:
# Total number of identified anomaly logs: 15
#                                                 label
# application_1445087491445_0002           Machine_down
# application_1445062781478_0012           Machine_down
# application_1445062781478_0013           Machine_down
# application_1445144423722_0023  Network_disconnection
# application_1445144423722_0024                 Normal
# application_1445182159119_0016           Machine_down
# application_1445062781478_0017           Machine_down
# application_1445175094696_0003  Network_disconnection
# application_1445087491445_0008           Machine_down
# application_1445175094696_0004  Network_disconnection
# application_1445076437777_0001           Machine_down
# application_1445094324383_0002           Machine_down
# application_1445094324383_0004           Machine_down
# application_1445094324383_0005           Machine_down
# application_1445144423722_0020  Network_disconnection

# %% [markdown]
# Predicting single log with Word2Vec on 'log' level with standard deviation 3

# %%
new_logline = 'CausedbyjavanetNoRouteToHostExceptionNoRoutetoHostfromMININTFNANLItomsrasafailedonsockettimeoutexceptionjavanetNoRouteToHostExceptionNoroutetohostnofurtherinformationFormoredetailsseehttpwikiapacheorghadoopNoRouteToHost'

# %%
is_anomaly1 = lad_with_kmeans(data, encoding_level = 'log', encoding_method = 'w2v', sd = 3, new_log = new_logline)
# Out:
# collecting all words and their counts
# PROGRESS: at sentence #0, processed 0 words, keeping 0 word types
# collected 1203 word types from a corpus of 394310 raw words and 1 sentences
# Loading a fresh vocabulary
# effective_min_count=1 retains 1203 unique words (100% of original 1203, drops 0)
# effective_min_count=1 leaves 394310 word corpus (100% of original 394310, drops 0)
# deleting the raw counts dictionary of 1203 items
# sample=0.001 downsamples 46 most-common words
# downsampling leaves estimated 169640 word corpus (43.0% of prior 394310)
# estimated required memory for 1203 words and 100 dimensions: 1563900 bytes
# resetting layer weights
# training model with 1 workers on 1203 vocabulary and 100 features, using sg=0 hs=0 sample=0.001 negative=5 window=3
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 1 : training on 394310 raw words (10000 effective words) took 0.0s, 671068 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 2 : training on 394310 raw words (10000 effective words) took 0.0s, 576556 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 3 : training on 394310 raw words (10000 effective words) took 0.0s, 557810 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 4 : training on 394310 raw words (10000 effective words) took 0.0s, 580489 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 5 : training on 394310 raw words (10000 effective words) took 0.0s, 600646 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 6 : training on 394310 raw words (10000 effective words) took 0.0s, 585542 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 7 : training on 394310 raw words (10000 effective words) took 0.0s, 774367 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 8 : training on 394310 raw words (10000 effective words) took 0.0s, 595045 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 9 : training on 394310 raw words (10000 effective words) took 0.0s, 574184 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 10 : training on 394310 raw words (10000 effective words) took 0.0s, 580019 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 11 : training on 394310 raw words (10000 effective words) took 0.0s, 788048 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 12 : training on 394310 raw words (10000 effective words) took 0.0s, 593420 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 13 : training on 394310 raw words (10000 effective words) took 0.0s, 785573 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 14 : training on 394310 raw words (10000 effective words) took 0.0s, 616019 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 15 : training on 394310 raw words (10000 effective words) took 0.0s, 877182 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 16 : training on 394310 raw words (10000 effective words) took 0.0s, 638727 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 17 : training on 394310 raw words (10000 effective words) took 0.0s, 617069 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 18 : training on 394310 raw words (10000 effective words) took 0.0s, 609893 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 19 : training on 394310 raw words (10000 effective words) took 0.0s, 583175 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 20 : training on 394310 raw words (10000 effective words) took 0.0s, 895752 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 21 : training on 394310 raw words (10000 effective words) took 0.0s, 616053 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 22 : training on 394310 raw words (10000 effective words) took 0.0s, 601445 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 23 : training on 394310 raw words (10000 effective words) took 0.0s, 632615 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 24 : training on 394310 raw words (10000 effective words) took 0.0s, 647095 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 25 : training on 394310 raw words (10000 effective words) took 0.0s, 598018 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 26 : training on 394310 raw words (10000 effective words) took 0.0s, 627430 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 27 : training on 394310 raw words (10000 effective words) took 0.0s, 981031 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 28 : training on 394310 raw words (10000 effective words) took 0.0s, 659111 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 29 : training on 394310 raw words (10000 effective words) took 0.0s, 647369 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 30 : training on 394310 raw words (10000 effective words) took 0.0s, 595884 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 31 : training on 394310 raw words (10000 effective words) took 0.0s, 647963 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 32 : training on 394310 raw words (10000 effective words) took 0.0s, 625255 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 33 : training on 394310 raw words (10000 effective words) took 0.0s, 647686 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 34 : training on 394310 raw words (10000 effective words) took 0.0s, 833340 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 35 : training on 394310 raw words (10000 effective words) took 0.0s, 628119 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 36 : training on 394310 raw words (10000 effective words) took 0.0s, 621837 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 37 : training on 394310 raw words (10000 effective words) took 0.0s, 675716 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 38 : training on 394310 raw words (10000 effective words) took 0.0s, 1051567 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 39 : training on 394310 raw words (10000 effective words) took 0.0s, 692754 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 40 : training on 394310 raw words (10000 effective words) took 0.0s, 870941 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 41 : training on 394310 raw words (10000 effective words) took 0.0s, 876995 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 42 : training on 394310 raw words (10000 effective words) took 0.0s, 630417 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 43 : training on 394310 raw words (10000 effective words) took 0.0s, 935076 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 44 : training on 394310 raw words (10000 effective words) took 0.0s, 645205 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 45 : training on 394310 raw words (10000 effective words) took 0.0s, 821047 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 46 : training on 394310 raw words (10000 effective words) took 0.0s, 686075 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 47 : training on 394310 raw words (10000 effective words) took 0.0s, 666345 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 48 : training on 394310 raw words (10000 effective words) took 0.0s, 664823 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 49 : training on 394310 raw words (10000 effective words) took 0.0s, 675762 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 50 : training on 394310 raw words (10000 effective words) took 0.0s, 958867 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 51 : training on 394310 raw words (10000 effective words) took 0.0s, 644421 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 52 : training on 394310 raw words (10000 effective words) took 0.0s, 674175 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 53 : training on 394310 raw words (10000 effective words) took 0.0s, 907139 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 54 : training on 394310 raw words (10000 effective words) took 0.0s, 711113 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 55 : training on 394310 raw words (10000 effective words) took 0.0s, 679118 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 56 : training on 394310 raw words (10000 effective words) took 0.0s, 706274 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 57 : training on 394310 raw words (10000 effective words) took 0.0s, 702840 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 58 : training on 394310 raw words (10000 effective words) took 0.0s, 1089625 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 59 : training on 394310 raw words (10000 effective words) took 0.0s, 941586 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 60 : training on 394310 raw words (10000 effective words) took 0.0s, 746162 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 61 : training on 394310 raw words (10000 effective words) took 0.0s, 725765 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 62 : training on 394310 raw words (10000 effective words) took 0.0s, 1031657 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 63 : training on 394310 raw words (10000 effective words) took 0.0s, 697477 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 64 : training on 394310 raw words (10000 effective words) took 0.0s, 691194 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 65 : training on 394310 raw words (10000 effective words) took 0.0s, 660469 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 66 : training on 394310 raw words (10000 effective words) took 0.0s, 658553 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 67 : training on 394310 raw words (10000 effective words) took 0.0s, 665233 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 68 : training on 394310 raw words (10000 effective words) took 0.0s, 680236 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 69 : training on 394310 raw words (10000 effective words) took 0.0s, 645852 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 70 : training on 394310 raw words (10000 effective words) took 0.0s, 658150 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 71 : training on 394310 raw words (10000 effective words) took 0.0s, 653285 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 72 : training on 394310 raw words (10000 effective words) took 0.0s, 668590 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 73 : training on 394310 raw words (10000 effective words) took 0.0s, 659077 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 74 : training on 394310 raw words (10000 effective words) took 0.0s, 674758 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 75 : training on 394310 raw words (10000 effective words) took 0.0s, 1048880 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 76 : training on 394310 raw words (10000 effective words) took 0.0s, 668408 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 77 : training on 394310 raw words (10000 effective words) took 0.0s, 712715 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 78 : training on 394310 raw words (10000 effective words) took 0.0s, 942827 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 79 : training on 394310 raw words (10000 effective words) took 0.0s, 665167 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 80 : training on 394310 raw words (10000 effective words) took 0.0s, 704377 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 81 : training on 394310 raw words (10000 effective words) took 0.0s, 883433 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 82 : training on 394310 raw words (10000 effective words) took 0.0s, 987107 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 83 : training on 394310 raw words (10000 effective words) took 0.0s, 673974 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 84 : training on 394310 raw words (10000 effective words) took 0.0s, 694488 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 85 : training on 394310 raw words (10000 effective words) took 0.0s, 659666 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 86 : training on 394310 raw words (10000 effective words) took 0.0s, 697925 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 87 : training on 394310 raw words (10000 effective words) took 0.0s, 652912 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 88 : training on 394310 raw words (10000 effective words) took 0.0s, 647082 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 89 : training on 394310 raw words (10000 effective words) took 0.0s, 879975 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 90 : training on 394310 raw words (10000 effective words) took 0.0s, 861396 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 91 : training on 394310 raw words (10000 effective words) took 0.0s, 1082270 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 92 : training on 394310 raw words (10000 effective words) took 0.0s, 715600 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 93 : training on 394310 raw words (10000 effective words) took 0.0s, 701276 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 94 : training on 394310 raw words (10000 effective words) took 0.0s, 717358 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 95 : training on 394310 raw words (10000 effective words) took 0.0s, 743265 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 96 : training on 394310 raw words (10000 effective words) took 0.0s, 1141542 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 97 : training on 394310 raw words (10000 effective words) took 0.0s, 752836 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 98 : training on 394310 raw words (10000 effective words) took 0.0s, 994556 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 99 : training on 394310 raw words (10000 effective words) took 0.0s, 706198 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 100 : training on 394310 raw words (10000 effective words) took 0.0s, 721204 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 101 : training on 394310 raw words (10000 effective words) took 0.0s, 716613 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 102 : training on 394310 raw words (10000 effective words) took 0.0s, 744394 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 103 : training on 394310 raw words (10000 effective words) took 0.0s, 728295 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 104 : training on 394310 raw words (10000 effective words) took 0.0s, 1148924 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 105 : training on 394310 raw words (10000 effective words) took 0.0s, 714531 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 106 : training on 394310 raw words (10000 effective words) took 0.0s, 707959 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 107 : training on 394310 raw words (10000 effective words) took 0.0s, 706180 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 108 : training on 394310 raw words (10000 effective words) took 0.0s, 728437 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 109 : training on 394310 raw words (10000 effective words) took 0.0s, 1143181 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 110 : training on 394310 raw words (10000 effective words) took 0.0s, 752594 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 111 : training on 394310 raw words (10000 effective words) took 0.0s, 722162 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 112 : training on 394310 raw words (10000 effective words) took 0.0s, 1122272 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 113 : training on 394310 raw words (10000 effective words) took 0.0s, 736017 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 114 : training on 394310 raw words (10000 effective words) took 0.0s, 697641 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 115 : training on 394310 raw words (10000 effective words) took 0.0s, 964815 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 116 : training on 394310 raw words (10000 effective words) took 0.0s, 727627 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 117 : training on 394310 raw words (10000 effective words) took 0.0s, 980863 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 118 : training on 394310 raw words (10000 effective words) took 0.0s, 727741 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 119 : training on 394310 raw words (10000 effective words) took 0.0s, 998103 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 120 : training on 394310 raw words (10000 effective words) took 0.0s, 1129886 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 121 : training on 394310 raw words (10000 effective words) took 0.0s, 745537 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 122 : training on 394310 raw words (10000 effective words) took 0.0s, 754666 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 123 : training on 394310 raw words (10000 effective words) took 0.0s, 772162 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 124 : training on 394310 raw words (10000 effective words) took 0.0s, 1129214 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 125 : training on 394310 raw words (10000 effective words) took 0.0s, 710440 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 126 : training on 394310 raw words (10000 effective words) took 0.0s, 932220 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 127 : training on 394310 raw words (10000 effective words) took 0.0s, 716654 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 128 : training on 394310 raw words (10000 effective words) took 0.0s, 751447 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 129 : training on 394310 raw words (10000 effective words) took 0.0s, 967957 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 130 : training on 394310 raw words (10000 effective words) took 0.0s, 733908 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 131 : training on 394310 raw words (10000 effective words) took 0.0s, 1062757 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 132 : training on 394310 raw words (10000 effective words) took 0.0s, 741237 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 133 : training on 394310 raw words (10000 effective words) took 0.0s, 698043 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 134 : training on 394310 raw words (10000 effective words) took 0.0s, 731601 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 135 : training on 394310 raw words (10000 effective words) took 0.0s, 701815 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 136 : training on 394310 raw words (10000 effective words) took 0.0s, 731387 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 137 : training on 394310 raw words (10000 effective words) took 0.0s, 709748 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 138 : training on 394310 raw words (10000 effective words) took 0.0s, 751426 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 139 : training on 394310 raw words (10000 effective words) took 0.0s, 732447 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 140 : training on 394310 raw words (10000 effective words) took 0.0s, 965036 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 141 : training on 394310 raw words (10000 effective words) took 0.0s, 763272 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 142 : training on 394310 raw words (10000 effective words) took 0.0s, 744861 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 143 : training on 394310 raw words (10000 effective words) took 0.0s, 717949 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 144 : training on 394310 raw words (10000 effective words) took 0.0s, 706198 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 145 : training on 394310 raw words (10000 effective words) took 0.0s, 684466 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 146 : training on 394310 raw words (10000 effective words) took 0.0s, 413384 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 147 : training on 394310 raw words (10000 effective words) took 0.0s, 650732 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 148 : training on 394310 raw words (10000 effective words) took 0.0s, 700237 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 149 : training on 394310 raw words (10000 effective words) took 0.0s, 681889 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 150 : training on 394310 raw words (10000 effective words) took 0.0s, 585885 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 151 : training on 394310 raw words (10000 effective words) took 0.0s, 469456 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 152 : training on 394310 raw words (10000 effective words) took 0.0s, 591631 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 153 : training on 394310 raw words (10000 effective words) took 0.0s, 687303 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 154 : training on 394310 raw words (10000 effective words) took 0.0s, 676541 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 155 : training on 394310 raw words (10000 effective words) took 0.0s, 656480 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 156 : training on 394310 raw words (10000 effective words) took 0.0s, 995448 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 157 : training on 394310 raw words (10000 effective words) took 0.0s, 922898 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 158 : training on 394310 raw words (10000 effective words) took 0.0s, 1096425 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 159 : training on 394310 raw words (10000 effective words) took 0.0s, 677935 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 160 : training on 394310 raw words (10000 effective words) took 0.0s, 707213 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 161 : training on 394310 raw words (10000 effective words) took 0.0s, 720470 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 162 : training on 394310 raw words (10000 effective words) took 0.0s, 951754 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 163 : training on 394310 raw words (10000 effective words) took 0.0s, 1098759 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 164 : training on 394310 raw words (10000 effective words) took 0.0s, 724455 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 165 : training on 394310 raw words (10000 effective words) took 0.0s, 708346 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 166 : training on 394310 raw words (10000 effective words) took 0.0s, 686480 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 167 : training on 394310 raw words (10000 effective words) took 0.0s, 716838 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 168 : training on 394310 raw words (10000 effective words) took 0.0s, 729535 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 169 : training on 394310 raw words (10000 effective words) took 0.0s, 685735 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 170 : training on 394310 raw words (10000 effective words) took 0.0s, 713561 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 171 : training on 394310 raw words (10000 effective words) took 0.0s, 715555 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 172 : training on 394310 raw words (10000 effective words) took 0.0s, 984958 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 173 : training on 394310 raw words (10000 effective words) took 0.0s, 1037322 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 174 : training on 394310 raw words (10000 effective words) took 0.0s, 735789 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 175 : training on 394310 raw words (10000 effective words) took 0.0s, 625023 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 176 : training on 394310 raw words (10000 effective words) took 0.0s, 647113 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 177 : training on 394310 raw words (10000 effective words) took 0.0s, 705224 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 178 : training on 394310 raw words (10000 effective words) took 0.0s, 706068 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 179 : training on 394310 raw words (10000 effective words) took 0.0s, 1114102 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 180 : training on 394310 raw words (10000 effective words) took 0.0s, 721846 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 181 : training on 394310 raw words (10000 effective words) took 0.0s, 938927 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 182 : training on 394310 raw words (10000 effective words) took 0.0s, 731535 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 183 : training on 394310 raw words (10000 effective words) took 0.0s, 709120 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 184 : training on 394310 raw words (10000 effective words) took 0.0s, 748831 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 185 : training on 394310 raw words (10000 effective words) took 0.0s, 767049 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 186 : training on 394310 raw words (10000 effective words) took 0.0s, 712211 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 187 : training on 394310 raw words (10000 effective words) took 0.0s, 777659 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 188 : training on 394310 raw words (10000 effective words) took 0.0s, 769583 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 189 : training on 394310 raw words (10000 effective words) took 0.0s, 945921 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 190 : training on 394310 raw words (10000 effective words) took 0.0s, 746170 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 191 : training on 394310 raw words (10000 effective words) took 0.0s, 710269 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 192 : training on 394310 raw words (10000 effective words) took 0.0s, 719771 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 193 : training on 394310 raw words (10000 effective words) took 0.0s, 744823 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 194 : training on 394310 raw words (10000 effective words) took 0.0s, 698020 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 195 : training on 394310 raw words (10000 effective words) took 0.0s, 934670 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 196 : training on 394310 raw words (10000 effective words) took 0.0s, 702765 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 197 : training on 394310 raw words (10000 effective words) took 0.0s, 685332 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 198 : training on 394310 raw words (10000 effective words) took 0.0s, 912192 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 199 : training on 394310 raw words (10000 effective words) took 0.0s, 902599 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 200 : training on 394310 raw words (10000 effective words) took 0.0s, 691974 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 201 : training on 394310 raw words (10000 effective words) took 0.0s, 662818 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 202 : training on 394310 raw words (10000 effective words) took 0.0s, 700860 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 203 : training on 394310 raw words (10000 effective words) took 0.0s, 686115 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 204 : training on 394310 raw words (10000 effective words) took 0.0s, 676644 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 205 : training on 394310 raw words (10000 effective words) took 0.0s, 672885 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 206 : training on 394310 raw words (10000 effective words) took 0.0s, 717044 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 207 : training on 394310 raw words (10000 effective words) took 0.0s, 708007 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 208 : training on 394310 raw words (10000 effective words) took 0.0s, 659867 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 209 : training on 394310 raw words (10000 effective words) took 0.0s, 677276 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 210 : training on 394310 raw words (10000 effective words) took 0.0s, 692425 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# ...
# EPOCH - 480 : training on 394310 raw words (10000 effective words) took 0.0s, 761562 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 481 : training on 394310 raw words (10000 effective words) took 0.0s, 767066 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 482 : training on 394310 raw words (10000 effective words) took 0.0s, 773280 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 483 : training on 394310 raw words (10000 effective words) took 0.0s, 1140683 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 484 : training on 394310 raw words (10000 effective words) took 0.0s, 749903 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 485 : training on 394310 raw words (10000 effective words) took 0.0s, 780964 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 486 : training on 394310 raw words (10000 effective words) took 0.0s, 776970 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 487 : training on 394310 raw words (10000 effective words) took 0.0s, 766012 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 488 : training on 394310 raw words (10000 effective words) took 0.0s, 722927 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 489 : training on 394310 raw words (10000 effective words) took 0.0s, 963106 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 490 : training on 394310 raw words (10000 effective words) took 0.0s, 765339 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 491 : training on 394310 raw words (10000 effective words) took 0.0s, 744588 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 492 : training on 394310 raw words (10000 effective words) took 0.0s, 730714 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 493 : training on 394310 raw words (10000 effective words) took 0.0s, 887847 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 494 : training on 394310 raw words (10000 effective words) took 0.0s, 734962 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 495 : training on 394310 raw words (10000 effective words) took 0.0s, 744427 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 496 : training on 394310 raw words (10000 effective words) took 0.0s, 760735 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 497 : training on 394310 raw words (10000 effective words) took 0.0s, 731272 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 498 : training on 394310 raw words (10000 effective words) took 0.0s, 743918 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 499 : training on 394310 raw words (10000 effective words) took 0.0s, 760492 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 500 : training on 394310 raw words (10000 effective words) took 0.0s, 774662 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 501 : training on 394310 raw words (10000 effective words) took 0.0s, 1036205 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 502 : training on 394310 raw words (10000 effective words) took 0.0s, 1019505 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 503 : training on 394310 raw words (10000 effective words) took 0.0s, 778223 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 504 : training on 394310 raw words (10000 effective words) took 0.0s, 954409 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 505 : training on 394310 raw words (10000 effective words) took 0.0s, 766123 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 506 : training on 394310 raw words (10000 effective words) took 0.0s, 742872 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 507 : training on 394310 raw words (10000 effective words) took 0.0s, 778611 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 508 : training on 394310 raw words (10000 effective words) took 0.0s, 965490 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 509 : training on 394310 raw words (10000 effective words) took 0.0s, 730275 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 510 : training on 394310 raw words (10000 effective words) took 0.0s, 776888 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 511 : training on 394310 raw words (10000 effective words) took 0.0s, 759094 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 512 : training on 394310 raw words (10000 effective words) took 0.0s, 757572 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 513 : training on 394310 raw words (10000 effective words) took 0.0s, 750811 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 514 : training on 394310 raw words (10000 effective words) took 0.0s, 774247 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 515 : training on 394310 raw words (10000 effective words) took 0.0s, 1019493 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 516 : training on 394310 raw words (10000 effective words) took 0.0s, 750598 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 517 : training on 394310 raw words (10000 effective words) took 0.0s, 736085 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 518 : training on 394310 raw words (10000 effective words) took 0.0s, 777126 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 519 : training on 394310 raw words (10000 effective words) took 0.0s, 717804 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 520 : training on 394310 raw words (10000 effective words) took 0.0s, 689958 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 521 : training on 394310 raw words (10000 effective words) took 0.0s, 719454 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 522 : training on 394310 raw words (10000 effective words) took 0.0s, 685269 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 523 : training on 394310 raw words (10000 effective words) took 0.0s, 717861 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 524 : training on 394310 raw words (10000 effective words) took 0.0s, 727888 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 525 : training on 394310 raw words (10000 effective words) took 0.0s, 751031 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 526 : training on 394310 raw words (10000 effective words) took 0.0s, 988768 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 527 : training on 394310 raw words (10000 effective words) took 0.0s, 1180950 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 528 : training on 394310 raw words (10000 effective words) took 0.0s, 1006658 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 529 : training on 394310 raw words (10000 effective words) took 0.0s, 757821 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 530 : training on 394310 raw words (10000 effective words) took 0.0s, 1132237 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 531 : training on 394310 raw words (10000 effective words) took 0.0s, 769371 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 532 : training on 394310 raw words (10000 effective words) took 0.0s, 775884 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 533 : training on 394310 raw words (10000 effective words) took 0.0s, 1125504 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 534 : training on 394310 raw words (10000 effective words) took 0.0s, 1017866 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 535 : training on 394310 raw words (10000 effective words) took 0.0s, 999686 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 536 : training on 394310 raw words (10000 effective words) took 0.0s, 770035 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 537 : training on 394310 raw words (10000 effective words) took 0.0s, 1032449 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 538 : training on 394310 raw words (10000 effective words) took 0.0s, 732724 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 539 : training on 394310 raw words (10000 effective words) took 0.0s, 781088 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 540 : training on 394310 raw words (10000 effective words) took 0.0s, 727152 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 541 : training on 394310 raw words (10000 effective words) took 0.0s, 1129250 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 542 : training on 394310 raw words (10000 effective words) took 0.0s, 676627 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 543 : training on 394310 raw words (10000 effective words) took 0.0s, 777549 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 544 : training on 394310 raw words (10000 effective words) took 0.0s, 1000751 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 545 : training on 394310 raw words (10000 effective words) took 0.0s, 737268 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 546 : training on 394310 raw words (10000 effective words) took 0.0s, 766595 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 547 : training on 394310 raw words (10000 effective words) took 0.0s, 1023634 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 548 : training on 394310 raw words (10000 effective words) took 0.0s, 1005381 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 549 : training on 394310 raw words (10000 effective words) took 0.0s, 769556 effective words/s
# job loop exiting, total 2 jobs
# worker exiting, processed 2 jobs
# worker thread finished; awaiting finish of 0 more threads
# EPOCH - 550 : training on 394310 raw words (10000 effective words) took 0.0s, 791849 effective words/s
# training on a 216870500 raw words (5500000 effective words) took 8.5s, 648148 effective words/s
# 53.06823992729187

# %%
print('Log "'+'\033[1m'+new_logline+'\033[0m'+'" is anomaly: '+'\033[1m'+str(is_anomaly1)+'\033[0m')
# Out:
# Log "INFOmainorgapachehadoopmapredYarnChildSleepingformsbeforeretryingagainGotnullnow" is anomaly: True

# %% [markdown]
# Predicting single log with Tf-idf on 'log' level with standard deviation 0.5

# %%
is_anomaly2 = lad_with_kmeans(data, encoding_level = 'log', encoding_method = 'tfidf', sd = 0.1, new_log = new_logline)

# %%
print('Log "'+'\033[1m'+new_logline+'\033[0m'+'" is anomaly: '+'\033[1m'+str(is_anomaly2)+'\033[0m')
# Out:
# Log "CausedbyjavanetNoRouteToHostExceptionNoRoutetoHostfromMININTFNANLItomsrasafailedonsockettimeoutexceptionjavanetNoRouteToHostExceptionNoroutetohostnofurtherinformationFormoredetailsseehttpwikiapacheorghadoopNoRouteToHost" is anomaly: True
